# %% [markdown]
# ## `yfinance_news.ipynb`

# %%
import yfinance as yf
import pandas as pd

# %%
news = yf.Ticker("AAPL").news
display(news)
# Out:
# [{'id': '6718e4b5-bd99-3460-97be-2a730c61527e',
#   'content': {'id': '6718e4b5-bd99-3460-97be-2a730c61527e',
#    'contentType': 'STORY',
#    'title': "YouTuber MKBHD Hails Tesla Model Y Performance, Calls EV Giant's Self-Driving Technology 'The Best'",
#    'description': '',
#    'summary': 'YouTuber Marques Brownlee, aka MKBHD, has shared his thoughts on the Tesla Inc. (NASDAQ:TSLA) Model Y Performance trim, as well as the company\'s self-driving technology. Tesla Self-Driving Is The Best Ever, MKBHD Says The YouTuber, in a review of the Model Y Performance on Thursday, hailed the crossover\'s software on the 16-inch touchscreen infotainment display, which is also a real-time representation of the car. "This is the best software in a car that is not Android Auto or Apple CarPlay," bo',
#    'pubDate': '2026-01-17T21:53:45Z',
#    'displayTime': '2026-01-17T21:53:45Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
# ...
