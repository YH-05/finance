# %% [markdown]
# # 個別銘柄分析\_基本データ.ipynb

# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import numpy as np
import curl_cffi
import pandas as pd
pd.options.display.precision = 2
import sqlite3
import json
import yfinance as yf
import datetime
from market_report_utils import MarketPerformanceAnalyzer
from fred_database_utils import store_fred_database, get_fred_ids_from_file  # type: ignore
from pathlib import Path
from typing import List

TICKER = "BKNG"

ROOT_DIR = Path().cwd().parent.parent
# FRED_DIR = ROOT_DIR / "15_Quant/data/FRED"
FRED_DIR = ROOT_DIR / "Quants/data/FRED"

# SECURITY_DIR = ROOT_DIR / f"19_Equity_Research/{TICKER}"
SECURITY_DIR = ROOT_DIR / f"Equity_Research/{TICKER}"
SECURITY_DATA_DIR = SECURITY_DIR / "data"
print(ROOT_DIR)
print(FRED_DIR)
print(SECURITY_DIR)
print(SECURITY_DATA_DIR)

db_path = FRED_DIR / "FRED.db"
id_list = get_fred_ids_from_file(file_path=FRED_DIR / "fred_series.json")

store_fred_database(db_path=db_path, series_id_list=id_list)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# c:\Users\Yuki Hata\Desktop\papers
# c:\Users\Yuki Hata\Desktop\papers\Quants\data\FRED
# c:\Users\Yuki Hata\Desktop\papers\Equity_Research\BKNG
# c:\Users\Yuki Hata\Desktop\papers\Equity_Research\BKNG\data
# --- FREDデータの差分更新を開始 (データベース: 'FRED.db') ---
# テーブル 'SP500' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'SP500' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'SP500' に更新データはありませんでした。
# テーブル 'CPIAUCSL' の最終日: 2025-09-01 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'CPIAUCSL' を取得中 (開始日: 2025-09-02)...
# 	シリーズ 'CPIAUCSL' に 1 件の新規データを追加しました。
# テーブル 'USEPUINDXD' の最終日: 2025-10-26 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'USEPUINDXD' を取得中 (開始日: 2025-10-27)...
# 	シリーズ 'USEPUINDXD' に更新データはありませんでした。
# テーブル 'DFF' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'DFF' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'DFF' に更新データはありませんでした。
# テーブル 'FEDFUNDS' の最終日: 2025-09-01 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'FEDFUNDS' を取得中 (開始日: 2025-09-02)...
# 	シリーズ 'FEDFUNDS' に 1 件の新規データを追加しました。
# テーブル 'SOFR' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'SOFR' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'SOFR' に更新データはありませんでした。
# テーブル 'DPRIME' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'DPRIME' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'DPRIME' に更新データはありませんでした。
# テーブル 'DTB3' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'DTB3' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'DTB3' に更新データはありませんでした。
# テーブル 'DGS1MO' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'DGS1MO' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'DGS1MO' に更新データはありませんでした。
# テーブル 'DGS3MO' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'DGS3MO' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'DGS3MO' に更新データはありませんでした。
# テーブル 'DGS6MO' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'DGS6MO' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'DGS6MO' に更新データはありませんでした。
# テーブル 'DGS1' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'DGS1' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'DGS1' に更新データはありませんでした。
# テーブル 'DGS2' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'DGS2' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'DGS2' に更新データはありませんでした。
# テーブル 'DGS3' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'DGS3' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'DGS3' に更新データはありませんでした。
# テーブル 'DGS5' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'DGS5' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'DGS5' に更新データはありませんでした。
# テーブル 'DGS7' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'DGS7' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'DGS7' に更新データはありませんでした。
# テーブル 'DGS10' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'DGS10' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'DGS10' に更新データはありませんでした。
# テーブル 'DGS20' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'DGS20' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'DGS20' に更新データはありませんでした。
# テーブル 'DGS30' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'DGS30' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'DGS30' に更新データはありませんでした。
# テーブル 'T10Y2Y' の最終日: 2025-10-27 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'T10Y2Y' を取得中 (開始日: 2025-10-28)...
# 	シリーズ 'T10Y2Y' に更新データはありませんでした。
# テーブル 'T10Y3M' の最終日: 2025-10-27 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'T10Y3M' を取得中 (開始日: 2025-10-28)...
# 	シリーズ 'T10Y3M' に更新データはありませんでした。
# テーブル 'T5YIE' の最終日: 2025-10-27 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'T5YIE' を取得中 (開始日: 2025-10-28)...
# 	シリーズ 'T5YIE' に更新データはありませんでした。
# テーブル 'T10YIE' の最終日: 2025-10-27 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'T10YIE' を取得中 (開始日: 2025-10-28)...
# 	シリーズ 'T10YIE' に更新データはありませんでした。
# テーブル 'DAAA' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'DAAA' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'DAAA' に更新データはありませんでした。
# テーブル 'DBAA' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'DBAA' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'DBAA' に更新データはありませんでした。
# テーブル 'BAMLC0A0CM' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'BAMLC0A0CM' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'BAMLC0A0CM' に更新データはありませんでした。
# テーブル 'BAMLH0A0HYM2' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'BAMLH0A0HYM2' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'BAMLH0A0HYM2' に更新データはありませんでした。
# テーブル 'MORTGAGE30US' の最終日: 2025-10-23 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'MORTGAGE30US' を取得中 (開始日: 2025-10-24)...
# 	シリーズ 'MORTGAGE30US' に更新データはありませんでした。
# テーブル 'BAMLC0A0CM' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'BAMLC0A0CM' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'BAMLC0A0CM' に更新データはありませんでした。
# テーブル 'BAMLH0A0HYM2' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'BAMLH0A0HYM2' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'BAMLH0A0HYM2' に更新データはありませんでした。
# テーブル 'BAMLC0A1CAAA' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'BAMLC0A1CAAA' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'BAMLC0A1CAAA' に更新データはありませんでした。
# テーブル 'BAMLC0A2CAA' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'BAMLC0A2CAA' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'BAMLC0A2CAA' に更新データはありませんでした。
# テーブル 'BAMLC0A3CA' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'BAMLC0A3CA' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'BAMLC0A3CA' に更新データはありませんでした。
# テーブル 'BAMLC0A4CBBB' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'BAMLC0A4CBBB' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'BAMLC0A4CBBB' に更新データはありませんでした。
# テーブル 'BAMLH0A1HYBB' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'BAMLH0A1HYBB' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'BAMLH0A1HYBB' に更新データはありませんでした。
# テーブル 'BAMLH0A2HYB' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'BAMLH0A2HYB' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'BAMLH0A2HYB' に更新データはありませんでした。
# テーブル 'BAMLH0A3HYC' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'BAMLH0A3HYC' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'BAMLH0A3HYC' に更新データはありませんでした。
# テーブル 'VIXCLS' の最終日: 2025-10-24 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'VIXCLS' を取得中 (開始日: 2025-10-25)...
# 	シリーズ 'VIXCLS' に更新データはありませんでした。
# テーブル 'PCEC' の最終日: 2025-04-01 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'PCEC' を取得中 (開始日: 2025-04-02)...
# 	シリーズ 'PCEC' に 1 件の新規データを追加しました。
# テーブル 'UNRATE' の最終日: 2025-08-01 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'UNRATE' を取得中 (開始日: 2025-08-02)...
# 	シリーズ 'UNRATE' に 1 件の新規データを追加しました。
# テーブル 'CES0500000003' の最終日: 2025-08-01 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'CES0500000003' を取得中 (開始日: 2025-08-02)...
# 	シリーズ 'CES0500000003' に 1 件の新規データを追加しました。
# テーブル 'PAYEMS' の最終日: 2025-08-01 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'PAYEMS' を取得中 (開始日: 2025-08-02)...
# 	シリーズ 'PAYEMS' に 1 件の新規データを追加しました。
# テーブル 'TOTCI' の最終日: 2025-10-15 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'TOTCI' を取得中 (開始日: 2025-10-16)...
# 	シリーズ 'TOTCI' に更新データはありませんでした。
# テーブル 'REALLN' の最終日: 2025-09-01 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'REALLN' を取得中 (開始日: 2025-09-02)...
# 	シリーズ 'REALLN' に 1 件の新規データを追加しました。
# テーブル 'CONSUMER' の最終日: 2025-09-01 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'CONSUMER' を取得中 (開始日: 2025-09-02)...
# 	シリーズ 'CONSUMER' に 1 件の新規データを追加しました。
# テーブル 'DPSACBW027SBOG' の最終日: 2025-10-15 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'DPSACBW027SBOG' を取得中 (開始日: 2025-10-16)...
# 	シリーズ 'DPSACBW027SBOG' に更新データはありませんでした。
# テーブル 'M2SL' の最終日: 2025-08-01 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'M2SL' を取得中 (開始日: 2025-08-02)...
# 	シリーズ 'M2SL' に 1 件の新規データを追加しました。
# テーブル 'M1SL' の最終日: 2025-08-01 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'M1SL' を取得中 (開始日: 2025-08-02)...
# 	シリーズ 'M1SL' に 1 件の新規データを追加しました。
# テーブル 'STLFSI4' の最終日: 2025-10-17 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'STLFSI4' を取得中 (開始日: 2025-10-18)...
# 	シリーズ 'STLFSI4' に更新データはありませんでした。
# テーブル 'UMCSENT' の最終日: 2025-09-01 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'UMCSENT' を取得中 (開始日: 2025-09-02)...
# 	シリーズ 'UMCSENT' に 1 件の新規データを追加しました。
# テーブル 'CSCICP03JPM665S' の最終日: 2024-01-01 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'CSCICP03JPM665S' を取得中 (開始日: 2024-01-02)...
# 	シリーズ 'CSCICP03JPM665S' に 1 件の新規データを追加しました。
# テーブル 'G7NAEXKP01IXOBSAQ' の最終日: 2018-01-01 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'G7NAEXKP01IXOBSAQ' を取得中 (開始日: 2018-01-02)...
# 	シリーズ 'G7NAEXKP01IXOBSAQ' に 1 件の新規データを追加しました。
# テーブル 'GDPC1' の最終日: 2025-04-01 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'GDPC1' を取得中 (開始日: 2025-04-02)...
# 	シリーズ 'GDPC1' に 1 件の新規データを追加しました。
# テーブル 'JPNRGDPEXP' の最終日: 2025-04-01 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'JPNRGDPEXP' を取得中 (開始日: 2025-04-02)...
# 	シリーズ 'JPNRGDPEXP' に 1 件の新規データを追加しました。
# テーブル 'CLVMNACSCAB1GQDE' の最終日: 2025-04-01 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'CLVMNACSCAB1GQDE' を取得中 (開始日: 2025-04-02)...
# 	シリーズ 'CLVMNACSCAB1GQDE' に 1 件の新規データを追加しました。
# テーブル 'NGDPRSAXDCGBQ' の最終日: 2025-01-01 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'NGDPRSAXDCGBQ' を取得中 (開始日: 2025-01-02)...
# 	シリーズ 'NGDPRSAXDCGBQ' に 1 件の新規データを追加しました。
# テーブル 'CLVMNACSCAB1GQFR' の最終日: 2025-04-01 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'CLVMNACSCAB1GQFR' を取得中 (開始日: 2025-04-02)...
# 	シリーズ 'CLVMNACSCAB1GQFR' に 1 件の新規データを追加しました。
# テーブル 'NGDPRSAXDCCAQ' の最終日: 2025-01-01 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'NGDPRSAXDCCAQ' を取得中 (開始日: 2025-01-02)...
# 	シリーズ 'NGDPRSAXDCCAQ' に 1 件の新規データを追加しました。
# テーブル 'CLVMNACSCAB1GQIT' の最終日: 2025-04-01 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'CLVMNACSCAB1GQIT' を取得中 (開始日: 2025-04-02)...
# 	シリーズ 'CLVMNACSCAB1GQIT' に 1 件の新規データを追加しました。
# テーブル 'CLVMNACSCAB1GQEA19' の最終日: 2025-04-01 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'CLVMNACSCAB1GQEA19' を取得中 (開始日: 2025-04-02)...
# 	シリーズ 'CLVMNACSCAB1GQEA19' に 1 件の新規データを追加しました。
# テーブル 'NGDPRSAXDCIDQ' の最終日: 2025-01-01 00:00:00。これ以降のデータを取得します。
# 	FREDシリーズ 'NGDPRSAXDCIDQ' を取得中 (開始日: 2025-01-02)...
# 	シリーズ 'NGDPRSAXDCIDQ' に 1 件の新規データを追加しました。
# --- 全てのFREDデータの差分更新が完了しました (データベース: 'FRED.db') ---

# %% [markdown]
# ## Price, PE and other valuation

# %%
def read_excel_data(excel_file: Path, sheet_name: str, variable: str) -> pd.DataFrame:
    df = pd.melt(
        pd.read_excel(excel_file, sheet_name=sheet_name)
        .rename(columns={"Unnamed: 0": "date"})
        .dropna(subset=["date"]),
        id_vars="date",
        var_name="Ticker",
        value_name="value",
    ).assign(variable=variable)

    return df


def read_excel_data_serial(
    excel_file: Path, sheet_name_list: List[str], variable_list: List[str]
) -> pd.DataFrame:
    dfs = []
    for sheet_name, variable in zip(sheet_name_list, variable_list):
        df = read_excel_data(
            excel_file=excel_file, sheet_name=sheet_name, variable=variable
        )
        dfs.append(df)

    df = pd.concat(dfs, ignore_index=True)

    return df


excel_file = SECURITY_DATA_DIR / f"{TICKER}_Price_Valuation.xlsx"
sheet_name_and_variable_name = {
    "Price": "Price",
    "Forward PE NTM": "Forward_PE_NTM",
    "Forward PE NTM - Index": "Forward_PE_NTM",
    "Actual PE LTM": "Actual_PE_LTM",
    "Actual PE LTM - Index": "Actual_PE_LTM",
}

df = read_excel_data_serial(
    excel_file=excel_file,
    sheet_name_list=sheet_name_and_variable_name.keys(),
    variable_list=sheet_name_and_variable_name.values(),
).drop_duplicates(ignore_index=True)
df = df.loc[df["Ticker"] != "GOOGL US Equity"].sort_values("date", ignore_index=True)
display(
    df.loc[(df["variable"] == "Price") & (df["Ticker"] == "ABNB US Equity")].dropna()
)
# Out:
#             date          Ticker   value variable
# 49565 2020-12-09  ABNB US Equity   68.00    Price
# 49581 2020-12-10  ABNB US Equity  144.71    Price
# 49598 2020-12-11  ABNB US Equity  139.25    Price
# 49612 2020-12-14  ABNB US Equity  130.00    Price
# 49631 2020-12-15  ABNB US Equity  124.80    Price
# ...          ...             ...     ...      ...
# 71532 2025-10-21  ABNB US Equity  128.56    Price
# 71557 2025-10-22  ABNB US Equity  127.50    Price
# 71584 2025-10-23  ABNB US Equity  127.35    Price
# 71592 2025-10-24  ABNB US Equity  127.99    Price
# 71608 2025-10-27  ABNB US Equity  129.07    Price
#
# [1226 rows x 4 columns]

# %% [markdown]
# ### cumulative return

# %%
start_date = "2021-1-1"
end_date = "2025-9-30"
df_price = df[
    (df["date"] >= start_date) & (df["date"] <= end_date) & (df["variable"] == "Price")
]
df_price = (
    pd.pivot(df_price, index="date", columns="Ticker", values="value")
    .reset_index()
    .sort_values("date", ignore_index=True)
    .set_index("date")
)
# df_price = (
#     pd.pivot(
#         df[df["variable"] == "Price"], index="date", columns="Ticker", values="value"
#     )
#     .reset_index()
#     .sort_values("date", ignore_index=True)
# ).set_index("date")
# df_price = df_price.iloc[-252 * 3 :, :].set_index("date")
# 累積リターン
df_cum_return = df_price.div(df_price.iloc[0])

fig = go.Figure()
for ticker in df_cum_return.columns:
    line_color = (
        "white" if ticker.startswith(TICKER) else None
    )  # Noneはテンプレートのデフォルト色を意味する
    line_width = 1.5 if ticker.startswith(TICKER) else 0.8
    name = ticker
    if ticker == "S5COND Index":
        name = "S&P500 Consumer Discretionary Index"
    elif ticker == "S5HOTL Index":
        name = "S&P500 Hotels, Restaurants & Leisure Index"

    fig.add_trace(
        go.Scatter(
            x=df_cum_return.index,
            y=df_cum_return[ticker],
            name=name,
            line=dict(width=line_width, color=line_color),
        )
    )


fig.update_layout(
    width=1000,
    height=500,
    template="plotly_dark",
    hovermode="x",
    legend=dict(yanchor="top", y=-0.05, xanchor="center", x=0.5, orientation="h"),
    margin=dict(l=40, r=40, t=50, b=60),
    title=f"Cumulative Return ({df_cum_return.index.min().strftime("%Y/%m/%d")}~{df_cum_return.index.max().strftime("%Y/%m/%d")})",
)

fig.show()

# %% [markdown]
# ## PE

# %% [markdown]
# ### Forward PE

# %%
df_forward_pe = pd.pivot(
    df[df["variable"] == "Forward_PE_NTM"],
    index="date",
    columns="Ticker",
    values="value",
).reset_index()
df_forward_pe = df_forward_pe.iloc[-252 * 5 : -1, :].set_index("date")


fig = go.Figure()
for ticker in df_forward_pe.columns:
    line_color = (
        "white" if ticker.startswith(TICKER) else None
    )  # Noneはテンプレートのデフォルト色を意味する
    line_width = 1.5 if ticker.startswith(TICKER) else 0.8
    name = ticker
    if ticker == "S5COND Index":
        name = "S&P500 Consumer Discretionary Index"
    elif ticker == "S5HOTL Index":
        name = "S&P500 Hotels, Restaurants & Leisure Index"
    fig.add_trace(
        go.Scatter(
            x=df_forward_pe.index,
            y=df_forward_pe[ticker],
            name=name,
            line=dict(width=line_width, color=line_color),
        )
    )

fig.update_yaxes(range=(0, 60))
fig.update_layout(
    width=1000,
    height=500,
    template="plotly_dark",
    hovermode="x",
    title="Forward PE",
    legend=dict(yanchor="top", y=-0.05, xanchor="center", x=0.5, orientation="h"),
    margin=dict(l=40, r=40, t=50, b=60),
)
fig.show()

# %%
df_actual_pe = df[(df["date"] >= start_date) & (df["variable"] == "Actual_PE_LTM")]
df_actual_pe = pd.pivot(
    df_actual_pe, index="date", columns="Ticker", values="value"
).sort_index()

fig = go.Figure()
for ticker in df_actual_pe.columns:
    line_color = (
        "white" if ticker.startswith(TICKER) else None
    )  # Noneはテンプレートのデフォルト色を意味する
    fig.add_trace(
        go.Scatter(
            x=df_actual_pe.index,
            y=df_actual_pe[ticker],
            name=ticker,
            line=dict(width=0.8, color=line_color),
        )
    )

fig.update_yaxes(range=(0, 60))
fig.update_layout(
    width=1000,
    height=500,
    template="plotly_dark",
    hovermode="x",
    title="Actual PE LTM",
    legend=dict(yanchor="top", y=-0.05, xanchor="center", x=0.5, orientation="h"),
    margin=dict(l=40, r=40, t=50, b=60),
)
fig.show()

for ticker in ["BKNG US Equity", "SPX Index", "S5HOTL Index"]:

    df_forward_and_actual_pe = df[
        (df["date"] >= start_date)
        & (df["variable"].isin(["Forward_PE_NTM", "Actual_PE_LTM"]))
        & (df["Ticker"].str.startswith(ticker))
    ]
    df_forward_and_actual_pe = pd.pivot(
        df_forward_and_actual_pe, index="date", columns="variable", values="value"
    ).sort_index()
    df_forward_and_actual_pe["Actual minus Forward"] = df_forward_and_actual_pe[
        "Actual_PE_LTM"
    ].sub(df_forward_and_actual_pe["Forward_PE_NTM"])

    fig = make_subplots(specs=[[{"secondary_y": True}]])
    for variable in [
        v for v in df_forward_and_actual_pe.columns if v != "Actual minus Forward"
    ]:
        fig.add_trace(
            go.Scatter(
                x=df_forward_and_actual_pe.index,
                y=df_forward_and_actual_pe[variable],
                name=variable,
                line=dict(width=0.8),
                yaxis="y1",
            ),
            secondary_y=False,
        )

    fig.add_trace(
        go.Scatter(
            x=df_forward_and_actual_pe.index,
            y=df_forward_and_actual_pe["Actual minus Forward"],
            name="Actual minus Forward",
            fill="tozeroy",
            mode="none",
            yaxis="y2",
        ),
        secondary_y=True,
    )
    fig.update_yaxes(range=(0, 60), title_text="PE(LTM / NTM)", secondary_y=False)
    fig.update_yaxes(
        range=(0, 20),
        title_text="Actual minus Forward",
        secondary_y=True,
        showgrid=False,
    )
    fig.update_layout(
        width=1000,
        height=500,
        template="plotly_dark",
        hovermode="x unified",
        legend=dict(yanchor="top", y=-0.05, xanchor="center", x=0.5, orientation="h"),
        margin=dict(l=40, r=40, t=50, b=60),
        title=f"{ticker} : Actual PE LTM and Forward PE NTM",
    )
    fig.show()
